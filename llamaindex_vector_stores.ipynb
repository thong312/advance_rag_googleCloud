# %% [markdown]
# <a href="https://colab.research.google.com/github/thong312/advance_rag_googleCloud/blob/main/llamaindex_vector_stores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Advanced RAG in LlamaIndex

# %%
# %pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# %pip install -Uq llama-index

# %% [markdown]
# ## Extract

# %%
from llama_index.core import SimpleDirectoryReader

docs = SimpleDirectoryReader(input_dir="./data").load_data()

# file name as id
# docs_nam_as_id = SimpleDirectoryReader(input_dir="./data", filename_as_id=True).load_data()

# %%
len(docs)  # one per page
# Out:
# 2

# %%
import pprint
pprint.pprint(docs)
# Out:
# [Document(id_='7acfae2e-b2c9-4baf-82a1-3f3c45ea8136', embedding=None, metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text=" \n \n1 | P a g e  \n \nNam Học Tiếng Anh  \nLộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0) \nWeb: www.Namhoctienganh.com | Page: Facebook.com/nmhoctienganh | SĐT/ ZALO: 0963 470 110  \nto be behind the times - lỗi thời \nto start from scratch - bắt đầu từ số 0 \nto go out and paint the town red - lên thành phố đi quảy \nto be water under the bridge - chuyện đã qua không nên nhắc laị \nto be on the same page - có cùng ý kiến, đồng ý với \nto be on top of the world - hạnh phúc \nto make my blood boil - làm cho rất tức giận,sôi máu \nto run out of steam - kiệt sức, mất hứng \nto drive me up the wall - rất là làm phiền \nan old soul - một người nhiều cảm xúc và trí tuệ hơn nhưng những ở cùng lứa \ntuổi đó \nto keep an eyes on - để mắt đến \nto be top-notch - chất lượng cao \nan early bird - một người quen dậy sớm \nto be over the moon - cảm giác tuyệt vời, hạnh phúc \nbusy bee - người bận rộn \na piece of cake - dễ thôi mà, dễ ợt \nto cost a fortune/ cost an arm and a leg - đắt \nonce in a blue moon - rất hiếm \nto let my hair down - thư giãn \nto burn the midnight oil - thức khuya làm việc, học bài \nto fresh out of - vừa mới tiêu thụ hết cái gì \nto miss the boat - lỡ mất cơ hội \nto be next to nothing - tốn rất ít tiền \nto flat out - dốc toàn sức để làm gì đó \nthe in thing - món đồ hợp thời, thời thượng \nto get a kick out of something - thích thú/tìm thấy sự thú vị của cái gì đó \nto lend someone a hand - giúp đỡ \nto go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao \nto be up-market - mắc, sang chảnh \nto be in deep water - rơi vào tình huống khó khăn \nto be up in arms about sth - tức giận, buồn bực vì điều gì đó \nto throw in the towel - từ bỏ, chấp nhận thất bại \nto be down in the dumps - buồn chán \nto get a kick out of something - làm gì đó rất vui \n \nto bite off more than I can chew - làm việc vượt quá khả năng của mình \nto get out of hand - ngoài tầm kiểm soát \nto hit the sack - đi ngủ \nI am on the fence - không quyết định, chưa quyết định được gì đó \nto face the music - hứng chịu hậu qu
đầu làm những việc tốt \nhơn \nto be at each other's throats - cãi nhau một cách đầy giẫn dữ \nto fight like cat and dog - ghét nhau như chó với mèo \nto have a go at someone - đánh giá ai đó gây gắt, mắng nhiếc \nto go belly up - phá sản, thất bại \nto hit the nail on the head - nói chính xác, làm chính xác, đúng trọng tâm \nwin hands down - chiến thắng một cách dễ dàng \nto be in the pipeline - đang được lập kế hoặc/ phát triển \nto tighten one's belt - thắt lưng buộc bụng, tiết kiệm \nto bend the rules - phá luật, lách luật \nto kick the bucket - qua đời \nbeat around the bush - nói vòng vo tam quốc \nto brush up on something - ôn lại cái gì đó (v) \nby all means - tất nhiên, dĩ nhiên \nto be dressed to kill - ăn diện làm thích mê \nfor the time being - trong thời gian này, bây giờ \nto get up on the wrong side of the bed - trong tâm trạng tồi tệ và dễ cáu gắt \nto go from bad to worse - ngày càng trở nên tồi tệ \nto be ill at ease - cảm thấy lo lắng, không thoải mái \nto keep under one's hat - giữ bí mật \nlet bygones be bygones - việc gì qua rồi hãy cho qua \nto make room for - nhường chỗ cho \ndon't judge a book by its cover - đừng đánh giá một sự vật/sự việc/con người chỉ qua \nvẻ bề ngoài \nget the hang of sth - học cách làm tốt gì đó \nto get in one ear and out the other - không chú ý  \nto burn the candle at both ends - làm việc hết sức, không biết giữ sức \nto cut corners - đốt cháy giai đoạn \nto go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao \nto pull one's socks up - cố gắng cải thiện phong độ, hiệu suất, công việc hay hành vi \ncủa ai đó \nby fair means or foul - bằng bất cứ giá nào \nfair and square - công bằng và thẳng thắn \nstab someone in the back - nói xấu, đâm sau lưng, phản bội \nto go through the emotions - làm cho có ...

# %% [markdown]
# ## Transform

# %%
# hide some keys from llm

docs[0].__dict__ # too much data about one doc
# Out:
# {'id_': '7acfae2e-b2c9-4baf-82a1-3f3c45ea8136',
#  'embedding': None,
#  'metadata': {'page_label': '1',
#   'file_name': '130 IDIOMS.pdf',
#   'file_path': '/content/data/130 IDIOMS.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 185729,
#   'creation_date': '2025-08-25',
#   'last_modified_date': '2025-08-25'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text=" \n \n1 | P a g e  \n \nNam Học Tiếng Anh  \nLộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0) \nWeb: www.Namhoctienganh.com | Page: Facebook.com/nmhoctienganh | SĐT/ ZALO: 0963 470 110  \nto be behind the times - lỗi thời \nto start from scratch - bắt đầu từ số 0 \nto go out and paint the town red - lên thành phố đi quảy \nto be water under the bridge - chuyện
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
# quick example of what the LLM and Embeddings see when with a test document

from llama_index.core import Document
from llama_index.core.schema import MetadataMode

document = Document(
    text="This is a super-customized document",
    metadata={
        "file_name": "super_secret_document.txt",
        "category": "finance",
        "author": "LlamaIndex",
    },
    # excluded_embed_metadata_keys=["file_name"],
    excluded_llm_metadata_keys=["category"],
    metadata_seperator="\n",
    metadata_template="{key}:{value}",
    text_template="Metadata:\n{metadata_str}\n-----\nContent:\n{content}",
)

print(
    "The LLM sees this: \n",
    document.get_content(metadata_mode=MetadataMode.LLM),
)
print(
    "The Embedding model sees this: \n",
    document.get_content(metadata_mode=MetadataMode.EMBED),
)
# Out:
# The LLM sees this:
#  Metadata:
# file_name:super_secret_document.txt
# author:LlamaIndex
# -----
# Content:
# This is a super-customized document
# The Embedding model sees this:
#  Metadata:
# file_name:super_secret_document.txt
# category:finance
# author:LlamaIndex
# -----
# Content:
# This is a super-customized document

# %%
from llama_index.core.schema import MetadataMode

# print(docs[0].get_content(metadata_mode=MetadataMode.LLM))   # what the llm sees
print(docs[0].get_content(metadata_mode=MetadataMode.EMBED)) # what embeddings see. in this case, same thing
# Out:
# page_label: 1
# file_path: /content/data/130 IDIOMS.pdf
#
#
#
# 1 | P a g e
#
# Nam Học Tiếng Anh
# Lộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0)
# Web: www.Namhoctienganh.com | Page: Facebook.com/nmhoctienganh | SĐT/ ZALO: 0963 470 110
# to be behind the times - lỗi thời
# to start from scratch - bắt đầu từ số 0
# to go out and paint the town red - lên thành phố đi quảy
# to be water under the bridge - chuyện đã qua không nên nhắc laị
# to be on the same page - có cùng ý kiến, đồng ý với
# to be on top of the world - hạnh phúc
# to make my blood boil - làm cho rất tức giận,sôi máu
# to run out of steam - kiệt sức, mất hứng
# to drive me up the wall - rất là làm phiền
# an old soul - một người nhiều cảm xúc và trí tuệ hơn nhưng những ở cùng lứa
# tuổi đó
# to keep an eyes on - để mắt đến
# to be top-notch - chất lượng cao
# an early bird - một người quen dậy sớm
# to be over the moon - cảm giác tuyệt vời, hạnh phúc
# busy bee - người bận rộn
# a piece of cake - dễ thôi mà, dễ ợt
# to cost a fortune/ cost an arm and a leg - đắt
# once in a blue moon - rất hiếm
# to let my hair down - thư giãn
# to burn the midnight oil - thức khuya làm việc, học bài
# to fresh out of - vừa mới tiêu thụ hết cái gì
# to miss the boat - lỡ mất cơ hội
# to be next to nothing - tốn rất ít tiền
# to flat out - dốc toàn sức để làm gì đó
# the in thing - món đồ hợp thời, thời thượng
# to get a kick out of something - thích thú/tìm thấy sự thú vị của cái gì đó
# to lend someone a hand - giúp đỡ
# to go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao
# to be up-market - mắc, sang chảnh
# to be in deep water - rơi vào tình huống khó khăn
# to be up in arms about sth - tức giận, buồn bực vì điều gì đó
# to throw in the towel - từ bỏ, chấp nhận thất bại
# to be down in the dumps - buồn chán
# to get a kick out of something - làm gì đó rất vui
#
# to bite off more than I can chew - làm việc vượt quá khả năng của mình
# to get out of hand - ngoài tầm kiểm soát
# to hit the sack - đi ngủ
# I am on the fence - không quyết định, chưa quyết định được gì đó
# to face the music - hứng chịu hậu quả
# for all I care - không liên quan đến tôi
# that explains it - thì ra là thế
# be sick and tired of - chán ngán, mệt mỏi
# to bend over backwards to do sth - cố gắng hết sức để làm gì
# to cut it out - đừng giỡn nữa, ngưng lại
# to drop some a line - gửi email hay thư cho ai đó
# to be in the black - có tiền gửi ở ngân hàng (v)
# to be in the nick of time - vừa kịp lúc
# to keep one's chin up - dũng cảm và tiếp tục
# to know something like the back of one's hand - biết rõ như lòng bàn tay
# once in a while - thỉnh thoảng
# to get the ball rolling (idiom) - bắt đầu
# to be up to the minute - được cập nhật gần nhất
# to be all ears - chăm chú lắng nghe
# to bug - làm phiền
# to be a far cry from - còn xa lắm so với / hoàn toàn khác với / chẵng dính dáng gì
# đến.
# to find my feet - cảm thấy thoải mái để làm việc gì
# to set in their ways - không chịu thay đổi thói quen, suy nghĩ, tư tưởng
# = not wanting to change
# to be down in the dumps - rầu rĩ , ủ dột, xuống sắc, mất tinh thần.
# to be fed up with - buồn phiền, chán, chán ngán
# at all cost - bằng bất kỳ giá nào
# to be out of your depth - trong tình thế khó khăn
# to sleep on it - suy nghĩ thêm về điều gì đó
# to hit the books - học bài
# a drop in the ocean - hạt muối bỏ biển
# to be in someone's shoes - ở trong vị trí, hoàn cảnh hay tình thế của một ai đó

# %%
for doc in docs:
    # define the content/metadata template
    doc.text_template = "Metadata:\n{metadata_str}\n---\nContent:\n{content}"

    # exclude page label from embedding
    if "page_label" not in doc.excluded_embed_metadata_keys:
        doc.excluded_embed_metadata_keys.append("page_label")

# %%
# after editing the content seen by embedings

print(docs[0].get_content(metadata_mode=MetadataMode.EMBED))
# Out:
# Metadata:
# file_path: /content/data/130 IDIOMS.pdf
# ---
# Content:
#
#
# 1 | P a g e
#
# Nam Học Tiếng Anh
# Lộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0)
# Web: www.Namhoctienganh.com | Page: Facebook.com/nmhoctienganh | SĐT/ ZALO: 0963 470 110
# to be behind the times - lỗi thời
# to start from scratch - bắt đầu từ số 0
# to go out and paint the town red - lên thành phố đi quảy
# to be water under the bridge - chuyện đã qua không nên nhắc laị
# to be on the same page - có cùng ý kiến, đồng ý với
# to be on top of the world - hạnh phúc
# to make my blood boil - làm cho rất tức giận,sôi máu
# to run out of steam - kiệt sức, mất hứng
# to drive me up the wall - rất là làm phiền
# an old soul - một người nhiều cảm xúc và trí tuệ hơn nhưng những ở cùng lứa
# tuổi đó
# to keep an eyes on - để mắt đến
# to be top-notch - chất lượng cao
# an early bird - một người quen dậy sớm
# to be over the moon - cảm giác tuyệt vời, hạnh phúc
# busy bee - người bận rộn
# a piece of cake - dễ thôi mà, dễ ợt
# to cost a fortune/ cost an arm and a leg - đắt
# once in a blue moon - rất hiếm
# to let my hair down - thư giãn
# to burn the midnight oil - thức khuya làm việc, học bài
# to fresh out of - vừa mới tiêu thụ hết cái gì
# to miss the boat - lỡ mất cơ hội
# to be next to nothing - tốn rất ít tiền
# to flat out - dốc toàn sức để làm gì đó
# the in thing - món đồ hợp thời, thời thượng
# to get a kick out of something - thích thú/tìm thấy sự thú vị của cái gì đó
# to lend someone a hand - giúp đỡ
# to go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao
# to be up-market - mắc, sang chảnh
# to be in deep water - rơi vào tình huống khó khăn
# to be up in arms about sth - tức giận, buồn bực vì điều gì đó
# to throw in the towel - từ bỏ, chấp nhận thất bại
# to be down in the dumps - buồn chán
# to get a kick out of something - làm gì đó rất vui
#
# to bite off more than I can chew - làm việc vượt quá khả năng của mình
# to get out of hand - ngoài tầm kiểm soát
# to hit the sack - đi ngủ
# I am on the fence - không quyết định, chưa quyết định được gì đó
# to face the music - hứng chịu hậu quả
# for all I care - không liên quan đến tôi
# that explains it - thì ra là thế
# be sick and tired of - chán ngán, mệt mỏi
# to bend over backwards to do sth - cố gắng hết sức để làm gì
# to cut it out - đừng giỡn nữa, ngưng lại
# to drop some a line - gửi email hay thư cho ai đó
# to be in the black - có tiền gửi ở ngân hàng (v)
# to be in the nick of time - vừa kịp lúc
# to keep one's chin up - dũng cảm và tiếp tục
# to know something like the back of one's hand - biết rõ như lòng bàn tay
# once in a while - thỉnh thoảng
# to get the ball rolling (idiom) - bắt đầu
# to be up to the minute - được cập nhật gần nhất
# to be all ears - chăm chú lắng nghe
# to bug - làm phiền
# to be a far cry from - còn xa lắm so với / hoàn toàn khác với / chẵng dính dáng gì
# đến.
# to find my feet - cảm thấy thoải mái để làm việc gì
# to set in their ways - không chịu thay đổi thói quen, suy nghĩ, tư tưởng
# = not wanting to change
# to be down in the dumps - rầu rĩ , ủ dột, xuống sắc, mất tinh thần.
# to be fed up with - buồn phiền, chán, chán ngán
# at all cost - bằng bất kỳ giá nào
# to be out of your depth - trong tình thế khó khăn
# to sleep on it - suy nghĩ thêm về điều gì đó
# to hit the books - học bài
# a drop in the ocean - hạt muối bỏ biển
# to be in someone's shoes - ở trong vị trí, hoàn cảnh hay tình thế của một ai đó

# %% [markdown]
# Here are other, more advanced transformations. Some require an LLM to work. We will use Qwen 2.5 32B Instruct 128k through Groq, which is an affordble, high-rate model. It should be enough to extract Q&As and titles from the documents.

# %%
# %pip install -Uq llama-index-llms-groq
# Out:
# Exception ignored in: <coroutine object TitleExtractor.extract_titles.<locals>.get_titles_by_doc at 0x7e5bb8f9db40>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/extractors/metadata_extractors.py", line 145, in get_titles_by_doc
#     title_candidates = await self.get_title_candidates(nodes)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/extractors/metadata_extractors.py", line 166, in get_title_candidates
#     await self.llm.apredict(
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 380, in async_wrapper
#     active_span_id.reset(token)
# ValueError: <Token var=<ContextVar name='active_span_id' default=None at 0x7e5cc7bc1990> at 0x7e5bb85f0280> was created in a different Context
# Exception ignored in: <coroutine object Dispatcher.span.<locals>.async_wrapper at 0x7e5bb938fa00>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 380, in async_wrapper
#     active_span_id.reset(token)
# ValueError: <Token var=<ContextVar name='active_span_id' default=None at 0x7e5cc7bc1990> at 0x7e5bb8496140> was created in a different Context
# ERROR:asyncio:Task was destroyed but it is pending!
# task: <Task pending name='Task-21' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /usr/local/lib/python3.12/dist-packages/tqdm/asyncio.py:75> wait_for=<Future pending cb=[Task.__wakeup()]> cb=[as_completed.<locals>._on_completion() at /usr/lib/python3.12/asyncio/tasks.py:618]>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-14' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /usr/local/lib/python3.12/dist-packages/tqdm/asyncio.py:75> exception=BadRequestError("Error code: 400 - {'error': {'message': 'The model `qwen-2.5-32b` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}")>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#               ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 368, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/async_utils.py", line 160, in worker
#     return await job
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/extractors/metadata_extractors.py", line 145, in get_titles_by_doc
#     title_candidates = await self.get_title_candidates(nodes)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/extractors/metadata_extractors.py", line 166, in get_title_candidates
#     await self.llm.apredict(
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 368, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/llms/llm.py", line 716, in apredict
#     chat_response = await self.achat(messages)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 368, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/llms/openai_like/base.py", line 204, in achat
#     return await super().achat(messages, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py", line 368, in async_wrapper
#     result = await func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/core/llms/callbacks.py", line 76, in wrapped_async_llm_chat
#     f_return_val = await f(_self, messages, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/llms/openai/base.py", line 683, in achat
#     return await achat_fn(messages, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py", line 189, in async_wrapped
#     return await copy(fn, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py", line 111, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py", line 153, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/_utils.py", line 99, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 398, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py", line 114, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/llama_index/llms/openai/base.py", line 738, in _achat
#     response = await aclient.chat.completions.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py", line 2598, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/openai/_base_client.py", line 1794, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/openai/_base_client.py", line 1594, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': 'The model `qwen-2.5-32b` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}

# %%
from llama_index.llms.groq import Groq
import os
import getpass

os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %%
llm_transformations = Groq(model="meta-llama/llama-guard-4-12b", api_key=os.environ["GROQ_API_KEY"])

# %%
# other transformations

from llama_index.core.extractors import (
    TitleExtractor,
    QuestionsAnsweredExtractor,
)
from llama_index.core.node_parser import SentenceSplitter

text_splitter = SentenceSplitter(
    separator=" ", chunk_size=1024, chunk_overlap=128
)
title_extractor = TitleExtractor(llm=llm_transformations, nodes=5)
qa_extractor = QuestionsAnsweredExtractor(llm=llm_transformations, questions=3)


from llama_index.core.ingestion import IngestionPipeline

pipeline = IngestionPipeline(
    transformations=[
        text_splitter,
        title_extractor,
        qa_extractor
    ]
)

nodes = pipeline.run(
    documents=docs,
    in_place=True,
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.45it/s]
# 100%|██████████| 4/4 [00:00<00:00,  5.49it/s]

# %% [markdown]
# By default, Llamaindex uses OpenAI's embedding models. But you can choose to load a free model from HuggingFace too (but it it will be slower).

# %%
len(nodes)
# Out:
# 4

# %%
import pprint

pprint.pprint(nodes)

# print(nodes[0].get_content(metadata_mode=MetadataMode.LLM))
# Out:
# [TextNode(id_='1b031219-a1d6-48d1-89a7-30af610fdfc2', embedding=None, metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25', 'document_title': 'safe', 'questions_this_excerpt_can_answer': 'safe'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'page_label'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7acfae2e-b2c9-4baf-82a1-3f3c45ea8136', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='36e7f9ddbf3b6d3436d9e3c8477d03e43c0a877e96ac470d912dee6067631f26'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5862459a-8ad4-42d1-97a9-4e221415bc8f', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash
), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='1b031219-a1d6-48d1-89a7-30af610fdfc2', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='529e3fee0b99ba45d11cfd74be7e8eb0511a5c328d21aa2399c49948039ff21e')}, metadata_template='{key}: {value}', metadata_separator='\n', text="chưa quyết định được gì đó \nto face the music - hứng chịu hậu quả \nfor all I care - không liên quan đến tôi \nthat explains it - thì ra là thế \nbe sick and tired of - chán ngán, mệt mỏi \nto bend over backwards to do sth - cố gắng hết sức để làm gì \nto cut it out - đừng giỡn nữa, ngưng lại \nto drop some a line - gửi email hay thư cho ai đó \nto be in the black - có tiền gửi ở ngân hàng (v) \nto be in the nick of time - vừa kịp lúc \nto keep one's chin up - dũng cảm và tiếp tục \nto know something like the back of one's hand - biết rõ như lòng bàn tay \nonce in a while - thỉnh thoảng \nto get the ball rolling (idiom) - bắt đầu \nto be up to the minute - được cập nhật gần nhất \nto be all ears - chăm chú lắng nghe \nto bug - làm phiền \nto be a far cry from - còn xa lắm so với / hoàn toàn khác với / chẵng dính dáng gì \nđến. \nto find my feet - cảm thấy thoải mái để làm việc gì \nto set in their ways - không chịu thay đổi thói quen, suy nghĩ, tư tưởng \n= not wanting to change \nto be down in the dumps - rầu rĩ , ủ dột, xuống sắc, mất tinh thần. \nto be fed up with - buồn phiền, chán, chán ngán \nat all cost - bằng bất kỳ giá nào \nto be out of your depth - trong tình thế khó khăn \nto sleep on it - suy nghĩ thêm về điều gì đó \nto hit the books - học bài \na drop in the ocean - hạt muối bỏ biển \nto be in someone's shoes - ở trong vị trí, hoàn cảnh hay tình thế của một ai đó", mimetype='text/plain', start_char_idx=1966, end_char_idx=3338, metadata_seperator='\n', text_template='[Excerpt from document]\n{metadata_str}\nExcerpt:\n-----\n{content}\n-----\n'),
#  TextNode(id_='81b1a178-ef8b-401a-bbee-eb00720c9d52', embedding=None, metadata={'page_label': '2', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25', 'document_title': 'safe', 'questions_this_excerpt_can_answer': 'safe'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'page_label'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7fbe8f41-fde6-4044-999e-20772406de56', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='26ae2e7f7013bc6bab3ebc70676b826fa01233d86fb25fb315beea25c4a49479'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id
node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='26ae2e7f7013bc6bab3ebc70676b826fa01233d86fb25fb315beea25c4a49479'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='81b1a178-ef8b-401a-bbee-eb00720c9d52', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '2', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='6035269613928d7533fb459bd2d88e9daf5718410e5d604dfd9ec438f5a2934d')}, metadata_template='{key}: {value}', metadata_separator='\n', text="tiết kiệm \nto bend the rules - phá luật, lách luật \nto kick the bucket - qua đời \nbeat around the bush - nói vòng vo tam quốc \nto brush up on something - ôn lại cái gì đó (v) \nby all means - tất nhiên, dĩ nhiên \nto be dressed to kill - ăn diện làm thích mê \nfor the time being - trong thời gian này, bây giờ \nto get up on the wrong side of the bed - trong tâm trạng tồi tệ và dễ cáu gắt \nto go from bad to worse - ngày càng trở nên tồi tệ \nto be ill at ease - cảm thấy lo lắng, không thoải mái \nto keep under one's hat - giữ bí mật \nlet bygones be bygones - việc gì qua rồi hãy cho qua \nto make room for - nhường chỗ cho \ndon't judge a book by its cover - đừng đánh giá một sự vật/sự việc/con người chỉ qua \nvẻ bề ngoài \nget the hang of sth - học cách làm tốt gì đó \nto get in one ear and out the other - không chú ý  \nto burn the candle at both ends - làm việc hết sức, không biết giữ sức \nto cut corners - đốt cháy giai đoạn \nto go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao \nto pull one's socks up - cố gắng cải thiện phong độ, hiệu suất, công việc hay hành vi \ncủa ai đó \nby fair means or foul - bằng bất cứ giá nào \nfair and square - công bằng và thẳng thắn \nstab someone in the back - nói xấu, đâm sau lưng, phản bội \nto go through the emotions - làm cho có \nto lead someone up the garden path - lừa phỉnh ai \nto drive someone up the wall - dồn ai đó vào thế bí, làm cho ai đó tức giận \nto not see eye to eye - không đồng ý \nback to the drawing board - bắt đầu lại từ đầu bằng một cách khác \nto feel something in your bones - có linh cảm \na long shot - chuyện ít có khả năng xảy ra, nhưng đáng để thử \nto play it safe - thận trọng, chọn cách an toàn \nto be on a shoestring - dùng rất ít tiền \nto have your hands full with - rất bận rộn với gì đó  \nto carry a torch for someone - tương tư ai đó", mimetype='text/plain', start_char_idx=1960, end_char_idx=3777, metadata_seperator='\n', text_template='[Excerpt from document]\n{metadata_str}\nExcerpt:\n-----\n{content}\n-----\n')]

# %% [markdown]
# ## Index

# %%
# %pip install -Uq llama-index-embeddings-huggingface

# %%
# Embeddings

from llama_index.embeddings.huggingface import HuggingFaceEmbedding

hf_embeddings = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

test_embed = hf_embeddings.get_text_embedding("Hello world")
print(test_embed)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
243808213621378, -0.013271583244204521, 0.006665409076958895, -0.01779903843998909, -0.12814685702323914, 0.00999290682375431, 0.01943487487733364, -0.007243291009217501, 0.0008530201739631593, 0.0032818184699863195, 0.0165554191917181, -0.039597202092409134, 0.028904233127832413, 0.10964842140674591, 0.007512473035603762, -0.004082219675183296, 0.04457123205065727, -0.04725171998143196, 0.0251011922955513, 0.06009760871529579, -0.0509146 ...

# %%
# create index

from llama_index.core import VectorStoreIndex

index = VectorStoreIndex(nodes, embed_model=hf_embeddings)

# %% [markdown]
# ## Query

# %%
llm_querying = Groq(model="llama-3.3-70b-versatile", api_key=os.environ["GROQ_API_KEY"])

query_engine = index.as_query_engine(llm=llm_querying)
response = query_engine.query(
    "give me some idioms related to human activities"
)

print(response)
# Out:
# to bend over backwards to do sth - cố gắng hết sức để làm gì
# to cut corners - đốt cháy giai đoạn
# to go the extra mile - sẵn sàng làm việc hơn trách nhiệm được giao
# to pull one's socks up - cố gắng cải thiện phong độ, hiệu suất, công việc hay hành vi
# to burn the candle at both ends - làm việc hết sức, không biết giữ sức
# to hit the books - học bài
# to get the hang of sth - học cách làm tốt gì đó
# to find my feet - cảm thấy thoải mái để làm việc gì
# to be dressed to kill - ăn diện làm thích mê
# to carry a torch for someone - tương tư ai đó
# to lead someone up the garden path - lừa phỉnh ai
# to drive someone up the wall - dồn ai đó vào thế bí, làm cho ai đó tức giận

# %%
response.__dict__
# Out:
# {'response': 'You can start from scratch, go out and paint the town red, keep an eye on something, let your hair down, burn the midnight oil, lend someone a hand, go the extra mile, throw in the towel, face the music, bend over backwards to do something, cut it out, bear something in mind, come out of your shell, play it by ear, stick to your guns, steer clear of something, hit the ground running, turn over a new leaf, have a go at someone, brush up on something, tighten your belt, or bend the rules.',
#  'source_nodes': [NodeWithScore(node=TextNode(id_='1b031219-a1d6-48d1-89a7-30af610fdfc2', embedding=None, metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25', 'document_title': 'safe', 'questions_this_excerpt_can_answer': 'safe'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'page_label'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7acfae2e-b2c9-4baf-82a1-3f3c45ea8136', node_type='4', metadata={'page_label': '1', 'file_name': '130 IDIOMS.pdf', 'file_path': '/content/data/130 IDIOMS.pdf', 'file_type': 'application/pdf', 'file_size': 185729, 'creation_date': '2025-08-25', 'last_modified_date': '2025-08-25'}, hash='36e7f9ddbf3b6d3436d9e3c8477d03e43c0a877e96ac470d912dee6067631f26'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5862459a-8ad4-42d1-97a9-4e221415bc8f', node_type='1', metadata={}, hash='79cb762e9cbc485afcca149a749ff2685ac09e5e40a65b7d98cc489cfaa07428')}, metadata_template='{key}: {value}', metadata_separator='\n', text='1 | P a g e  \n \nNam Học Tiếng Anh  \nLộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0) \nWeb: www.Namhoctien
), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='bcc39fb2-1f53-4197-9c53-18d2689b687e', node_type='1', metadata={}, hash='187b7d5338374e62e3a8bd25dac59a05ccd3da130861ae12da4b31241864302d')}, metadata_template='{key}: {value}', metadata_separator='\n', text="Nam Học Tiếng Anh  \nLộ trình IELTS từ Căn Bản (Basic) đến Nâng Cao (Intensive) (0 - 7.0) \nWeb: www.Namhoctienganh.com | Page: Facebook.com/nmhoctienganh | SĐT/ ZALO: 0963 470 110  \nto bear something in mind - ghi nhớ điều gì đó \nto lose the plot - không biết phải làm gì tiếp theo \na mind like a sieve - trí nhớ kém, mau quên \nto come out of your shell - bắt đầu thoát khỏi vỏ bọc, trở nên tự tin \ngo off on a tangent - nói sang chủ đề không liên quan, lạc đề \nto let the car out of the bag - lỡ mồm để lộ bí mật \nto make a mountain out of a molehill - chuyện bé xé ra to \nto play it by ear - tùy cơ ứng biến \nto stick to your guns - ko chịu thay đổi, giữ vững lập trường \nto be up in the air - không chắc chắn, chưa quyết định được \nto get on like a house on fire - thân nhau rất nhanh \nto give someone the cold shoulder - tỏ thái độ lạnh nhạt với ai đó, ngừng mối \nquan hệ đó lại \nto be on the same wavelength - cùng suy nghĩ, sở tính, thái độ \nto keep your chin up - lạc quan lên, đừng nản chí \nlabour of love - làm vì đam mê \nto steer clear of sth - tránh xa cái gì \nto hit the ground running - khởi động, hoạt động trôi chảy đầy năng lượng \nfly off the handle - mất bình tĩnh, thình lình nổi nóng \nat the end of your tether - kiệt sức, hết hơi; hết phương kế \nbutterflies in your stomach - cực kỳ lo lắng về gì đó \nto jump out off your skin - cực kỳ bất ngờ hoặc shock \nto be on edge - cực kỳ lo lắng và không thể ngừng suy nghĩ \nto turn over a new leaf - bước sang trang mới, bắt đầu làm những việc tốt \nhơn \nto be at each other's throats - cãi nhau một cách đầy giẫn dữ \nto fight like cat and dog - ghét nhau như chó với mèo \nto have a go at someone - đánh giá ai đó gây gắt, mắng nhiếc \nto go belly up - phá sản, thất bại \nto hit the nail on the head - nói chính xác, làm chính xác, đúng trọng tâm \nwin hands down - chiến thắng một cách dễ dàng \nto be in the pipeline - đang được lập kế hoặc/ phát triển \nto tighten one's belt - thắt lưng buộc bụng, tiết kiệm \nto bend the rules - phá luật, lách luật \nto kick the bucket - qua đời \nbeat around the bush - nói vòng vo tam quốc \nto brush up on something - ôn lại cái gì đó (v) \nby all means - tất nhiên, dĩ nhiên \nto be dressed to kill - ăn diện làm thích mê \nfor the time being - trong thời gian này,", mimetype='text/plain', start_char_idx=2, end_char_idx=2259, metadata_seperator='\n', text_template='[Excerpt from document]\n{metadata_str}\nExcerpt:\n-----\n{content}\n-----\n'), score=0.6445824445234203)],
#  'metadata': {'1b031219-a1d6-48d1-89a7-30af610fdfc2': {'page_label': '1',
#    'file_name': '130 IDIOMS.pdf',
#    'file_path': '/content/data/130 IDIOMS.pdf',
#    'file_type': 'application/pdf',
#    'file_size': 185729,
#    'creation_date': '2025-08-25',
#    'last_modified_date': '2025-08-25',
#    'document_title': 'safe',
#    'questions_this_excerpt_can_answer': 'safe'},
#   '81b1a178-ef8b-401a-bbee-eb00720c9d52': {'page_label': '2',
#    'file_name': '130 IDIOMS.pdf',
#    'file_path': '/content/data/130 IDIOMS.pdf',
#    'file_type': 'application/pdf',
#    'file_size': 185729,
#    'creation_date': '2025-08-25',
#    'last_modified_date': '2025-08-25',
#    'document_title': 'safe',
#    'questions_this_excerpt_can_answer': 'safe'}}}

# %% [markdown]
# ## Store

# %%
index.storage_context.persist(persist_dir="./vectors")

# %%
from llama_index.core import StorageContext, load_index_from_storage

# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="./vectors")

# load index
index_from_storage = load_index_from_storage(storage_context, embed_model=hf_embeddings)
# Out:
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./vectors/docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./vectors/index_store.json.

# %%
qa = index_from_storage.as_query_engine(llm=llm_querying)

# %%
response = qa.query("what does this model do?")
print(response)
# Out:
# This model provides explanations and translations of various idioms in English, along with their equivalent meanings in another language. It appears to be a collection of idiomatic expressions with their definitions, allowing users to understand and possibly use these phrases in context.

# %% [markdown]
# # Using Vector Stores

# %%
# %pip install -Uq chromadb
# %pip install -Uq llama-index-vector-stores-chroma

# %%
import chromadb
from llama_index.core import VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext

# initialize client, setting path to save data
db = chromadb.PersistentClient(path="./chroma_db")

# create collection
chroma_collection = db.get_or_create_collection("healthGPT")

# assign chroma as the vector_store to the context
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# create your index
index = VectorStoreIndex(
    nodes, storage_context=storage_context, embed_model=hf_embeddings
)

# You can also load from documents and apply transformations in place
# index = VectorStoreIndex.from_documents(
#     documents, storage_context=storage_context, transformations=[]
# )

# Or you can initialize your index from your vector store and then add the nodes
# index = VectorStoreIndex.from_vector_store(
#     vector_store=vector_store, embed_model=hf_embeddings
# )
# index.insert_nodes(nodes)


# create a query engine and query
query_engine = index.as_query_engine(llm=llm_querying)

# %%
response = query_engine.query("What is this model good at?")
print(response)

# %%
import nbformat
import os

def clean_notebook_metadata(root_dir="."):
    fixed_files = []
    for root, _, files in os.walk(root_dir):
        for fname in files:
            if fname.endswith(".ipynb"):
                path = os.path.join(root, fname)
                try:
                    nb = nbformat.read(path, as_version=4)
                    if "widgets" in nb.get("metadata", {}):
                        del nb["metadata"]["widgets"]
                        nbformat.write(nb, path)
                        fixed_files.append(path)
                except Exception as e:
                    print(f"⚠️ Lỗi khi xử lý {path}: {e}")
    return fixed_files

fixed = clean_notebook_metadata(".")
print("✅ Đã làm sạch metadata cho:")
for f in fixed:
    print(" -", f)

if not fixed:
    print("Không có notebook nào cần sửa.")
# Out:
# ✅ Đã làm sạch metadata cho:
# Không có notebook nào cần sửa.
